# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime



# adress = r"C:\Users\Cash\Documents\pruebas_python\proyectos\analisis de datos\archive (3)\fatalities_isr_pse_conflict_2000_to_2023.csv"
adress = r"fatalities_isr_pse_conflict_2000_to_2023.csv"


df = pd.read_csv(adress, low_memory = False, parse_dates = ["date_of_event"])
df
# Out:
#                                               name date_of_event   age  \
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
#        citizenship     event_location event_location_district  \
# ...

# %%
#Number of palestinians and israelis deaths during the conflict
print(f'The number of palestinians and israelis deaths during the conflict is {df.loc[(df["citizenship"] == "Palestinian") |(df["citizenship"] == "Israeli"),"citizenship"].count()}')
df.loc[(df["citizenship"] == "Palestinian") |(df["citizenship"] == "Israeli")]
# Out:
# The number of palestinians and israelis deaths during the conflict is 11121
#                                               name date_of_event   age  \
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
# ...

# %%
# Year of most deaths number
# df_copy = df.copy()
x = df["date_of_event"].value_counts().reset_index().loc[0,"date_of_event"]
print(f'The year of most deaths number is {x}')
df["date_of_event"].value_counts().reset_index()
# Out:
# The year of most deaths number is 2014
#     date_of_event  count
# 0            2014   2332
# 1            2002   1325
# 2            2009   1045
# 3            2004    928
# 4            2008    915
# 5            2003    733
# 6            2006    684
# 7            2007    395
# 8            2001    353
# 9            2021    325
# 10           2018    302
# 11           2012    261
# 12           2023    249
# 13           2005    234
# 14           2022    205
# 15           2015    177
# 16           2019    145
# 17           2011    129
# 18           2016    116
# 19           2010     89
# 20           2017     76
# 21           2013     41
# 22           2000     35
# 23           2020     30
